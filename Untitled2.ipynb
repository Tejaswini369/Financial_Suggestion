# %%
pip install streamlit transformers pandas requests langchain
# Out:
# Requirement already satisfied: streamlit in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (1.37.0)
# Requirement already satisfied: transformers in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (4.43.3)
# Requirement already satisfied: pandas in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (2.0.3)
# Requirement already satisfied: requests in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (2.32.3)
# Requirement already satisfied: langchain in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (0.2.11)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (4.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (10.4.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.27.3-cp38-cp38-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: filelock in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (0.24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (0.2.24)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (0.1.93)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jinja2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain) (3.0.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (6.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair<6,>=4.0->streamlit) (3.17.0)
# Downloading protobuf-5.27.3-cp38-cp38-win_amd64.whl (426 kB)
#    ---------------------------------------- 0.0/426.9 kB ? eta -:--:--
#    - ------------------------------------- 20.5/426.9 kB 320.0 kB/s eta 0:00:02
#    ---- ---------------------------------- 51.2/426.9 kB 518.5 kB/s eta 0:00:01
#    ------------- -------------------------- 143.4/426.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 426.9/426.9 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed protobuf-5.27.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\kteja\anaconda3\envs\llm_finance\Lib\site-packages\google\~rotobuf'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.27.3 which is incompatible.
# tensorflow-gpu 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.27.3 which is incompatible.

# %%
import streamlit as st
import pandas as pd
import json
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain

# Load datasets
stock_data = pd.read_csv('100_stocks_data_new.csv', index_col='Date')
financial_data = pd.read_csv('financial_statements_fmp.csv')
news_data = pd.read_csv('news_articles_100_tickers.csv')

# Transform stock data to have a ticker column
stock_data = stock_data.reset_index().melt(id_vars='Date', var_name='ticker', value_name='price')

# Define prompt template
template = """
Based on the following data, provide an investment suggestion for the ticker {ticker}:
Stock Data: {stock_data}
Financial Data: {financial_data}
News Data: {news_data}

Suggestion:
"""

prompt = PromptTemplate(
    input_variables=["ticker", "stock_data", "financial_data", "news_data"],
    template=template
)

# Load LLM from Hugging Face
llm = HuggingFaceHub(
    repo_id="distilgpt2", 
    model_kwargs={"use_auth_token": "YOUR_HF_AUTH_TOKEN"},
    huggingfacehub_api_token="YOUR_HF_AUTH_TOKEN"
)

# Define LLM Chain
llm_chain = LLMChain(prompt=prompt, llm=llm)

def combine_data_for_ticker(ticker):
    stock_info = stock_data[stock_data['ticker'] == ticker].to_dict(orient='records')
    financial_info = financial_data[financial_data['ticker'] == ticker].to_dict(orient='records')
    news_info = news_data[news_data['ticker'] == ticker].to_dict(orient='records')
    
    combined_data = {
        'ticker': ticker,
        'stock_info': stock_info,
        'financial_info': financial_info,
        'news_info': news_info
    }
    
    return combined_data

def get_investment_suggestion(ticker):
    combined_data = combine_data_for_ticker(ticker)
    stock_info = json.dumps(combined_data['stock_info'], indent=2)
    financial_info = json.dumps(combined_data['financial_info'], indent=2)
    news_info = json.dumps(combined_data['news_info'], indent=2)
    
    suggestion = llm_chain.run(
        ticker=ticker,
        stock_data=stock_info,
        financial_data=financial_info,
        news_data=news_info
    )
    return suggestion

# Streamlit app
st.title("Investment Suggestion Chatbot")
st.write("Enter a ticker symbol to get an investment suggestion based on stock, financial, and news data.")

ticker_input = st.text_input("Ticker Symbol (e.g., AAPL)").upper()

if st.button("Get Suggestion"):
    if ticker_input:
        suggestion = get_investment_suggestion(ticker_input)
        st.write(f"Investment Suggestion for {ticker_input}:")
        st.write(suggestion)
    else:
        st.write("Please enter a ticker symbol.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\utils\import_utils.py:1586, in _LazyModule._get_module(self, module_name)
#    1585 try:
# -> 1586     return importlib.import_module("." + module_name, self.__name__)
#    1587 except Exception as e:
#
# File ~\anaconda3\envs\llm_finance\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\pipelines\__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\image_processing_utils.py:21
#      20 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 21 from .image_transforms import center_crop, normalize, rescale
#      22 from .image_utils import ChannelDimension
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\image_transforms.py:49
#      48 if is_tf_available():
# ---> 49     import tensorflow as tf
#      51 if is_flax_available():
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\__init__.py:37
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\python\__init__.py:37
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\python\eager\context.py:29
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\core\framework\function_pb2.py:16
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\google\protobuf\descriptor.py:621, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     615 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     616             default_value, message_type, enum_type, containing_type,
#     617             is_extension, extension_scope, options=None,
#     618             serialized_options=None,
#     619             has_default_value=True, containing_oneof=None, json_name=None,
#     620             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 621   _message.Message._CheckCalledFromGeneratedFile()
#     622   if is_extension:
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 import json
# ----> 4 from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
#       5 from langchain.llms import HuggingFaceHub
#       6 from langchain import PromptTemplate, LLMChain
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\utils\import_utils.py:1576, in _LazyModule.__getattr__(self, name)
#    1574     value = self._get_module(name)
#    1575 elif name in self._class_to_module.keys():
# -> 1576     module = self._get_module(self._class_to_module[name])
#    1577     value = getattr(module, name)
#    1578 else:
#
# File ~\anaconda3\envs\llm_finance\lib\site-packages\transformers\utils\import_utils.py:1588, in _LazyModule._get_module(self, module_name)
#    1586     return importlib.import_module("." + module_name, self.__name__)
#    1587 except Exception as e:
# -> 1588     raise RuntimeError(
#    1589         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1590         f" traceback):\n{e}"
#    1591     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
