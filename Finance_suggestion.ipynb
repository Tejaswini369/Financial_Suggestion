# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\kteja\anaconda3\envs\llm_finance\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\kteja\AppData\Local\Temp\ipykernel_2088\3326022288.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15547186263462021276
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15752852091200664082
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain
import pandas as pd
import json

# Load datasets
stock_data = pd.read_csv('100_stocks_data_new.csv', index_col='Date')
financial_data = pd.read_csv('financial_statements_fmp.csv')
news_data = pd.read_csv('news_articles_100_tickers.csv')

# Transform stock data to have a ticker column
stock_data = stock_data.reset_index().melt(id_vars='Date', var_name='ticker', value_name='price')


# Define prompt template
template = """
Based on the following data, provide an investment suggestion for the ticker {ticker}:
Stock Data: {stock_data}
Financial Data: {financial_data}
News Data: {news_data}

Suggestion:
"""

prompt = PromptTemplate(
    input_variables=["ticker", "stock_data", "financial_data", "news_data"],
    template=template
)

# Load LLM from Hugging Face with the API token
llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3", 
    model_kwargs={"use_auth_token": "YOUR_HF_AUTH_TOKEN"},
    huggingfacehub_api_token="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"
)

# Define LLM Chain
llm_chain = LLMChain(prompt=prompt, llm=llm)

def combine_data_for_ticker(ticker):
    stock_info = stock_data[stock_data['ticker'] == ticker].to_dict(orient='records')
    financial_info = financial_data[financial_data['ticker'] == ticker].to_dict(orient='records')
    news_info = news_data[news_data['ticker'] == ticker].to_dict(orient='records')
    
    combined_data = {
        'ticker': ticker,
        'stock_info': stock_info,
        'financial_info': financial_info,
        'news_info': news_info
    }
    
    return combined_data

def get_investment_suggestion(ticker):
    combined_data = combine_data_for_ticker(ticker)
    stock_info = json.dumps(combined_data['stock_info'], indent=2)
    financial_info = json.dumps(combined_data['financial_info'], indent=2)
    news_info = json.dumps(combined_data['news_info'], indent=2)
    
    suggestion = llm_chain.run(
        ticker=ticker,
        stock_data=stock_info,
        financial_data=financial_info,
        news_data=news_info
    )
    return suggestion

def prompt_user_for_ticker():
    ticker = input("Enter the ticker symbol (e.g., AAPL): ").upper()
    suggestion = get_investment_suggestion(ticker)
    print(f"Investment Suggestion for {ticker}:")
    print(suggestion)

# Example usage
prompt_user_for_ticker()
# Out:
# Enter the ticker symbol (e.g., AAPL):  UNP
# Investment Suggestion for UNP:
#
# Based on the following data, provide an investment suggestion for the ticker UNP:
# Stock Data: [
#   {
#     "Date": "2023-09-14",
#     "ticker": "UNP",
#     "price": 1.0
#   },
#   {
#     "Date": "2023-09-15",
#     "ticker": "UNP",
#     "price": 0.9889662046467506
#   },
#   {
#     "Date": "2023-09-18",
#     "ticker": "UNP",
#     "price": 0.9881780107193524
#   },
#   {
#     "Date": "2023-09-19",
#     "ticker": "UNP",
#     "price": 0.9817802840455104
#   },
#   {
#     "Date": "2023-09-20",
#     "ticker": "UNP",
#     "price": 0.9873898875327486
#   },
#   {
#     "Date": "2023-09-21",
#     "ticker": "UNP",
#     "price": 0.9800648905303896
#   },
#   {
#     "Date": "2023-09-22",
#     "ticker": "UNP",
#     "price": 0.9700510359458734
#   },
#   {
#     "Date": "2023-09-25",
#     "ticker": "UNP",
#     "price": 0.9665275784754156
#   },
#   {
#     "Date": "2023-09-26",
#     "ticker": "UNP",
#     "price": 0.9496522913120048
#   },
#   {
#     "Date": "2023-09-27",
#     "ticker": "UNP",
#     "price": 0.9383402724157238
#   },
#   {
#     "Date": "2023-09-28",
#     "ticker": "UNP",
#     "price": 0.9462679809834598
#   },
#   {
#     "Date": "2023-09-29",
#     "ticker": "UNP",
#     "price": 0.9440426878247664
#   },
#   {
#     "Date": "2023-10-02",
#     "ticker": "UNP",
#     "price": 0.9394529543654676
#   },
#   {
#     "Date": "2023-10-03",
#     "ticker": "UNP",
#     "price": 0.94473806983036
#   },
#   {
#     "Date": "2023-10-04",
#     "ticker": "UNP",
#     "price": 0.9377376315911408
#   },
#   {
#     "Date": "2023-10-05",
#     "ticker": "UNP",
#     "price": 0.9301808170066528
#   },
#   {
#     "Date": "2023-10-06",
#     "ticker": "UNP",
#     "price": 0.9386184959587552
#   },
#   {
#     "Date": "2023-10-09",
#     "ticker": "UNP",
#     "price": 0.947148845351074
#   },
#   {
#     "Date": "2023-10-10",
#     "ticker": "UNP",
#     "price": 0.956652800292018
#   },
#   {
#     "Date": "2023-10-11",
#     "ticker": "UNP",
#     "price": 0.971163647154823
#   },
#   {
#     "Date": "2023-10-12",
#     "ticker": "UNP",
#     "price": 0.9642559500966142
#   },
#   {
#     "Date": "2023-10-13",
#     "ticker": "UNP",
#     "price": 0.9631432681468706
#   },
#   {
#     "Date": "2023-10-16",
#     "ticker": "UNP",
#     "price": 0.9774223681683404
#   },
#   {
#     "Date": "2023-10-17",
#     "ticker": "UNP",
#     "price": 0.9797867377281524
#   },
#   {
#     "Date": "2023-10-18",
#     "ticker": "UNP",
#     "price": 0.95465925397466
#   },
#   {
#     "Date": "2023-10-19",
#     "ticker": "UNP",
#     "price": 0.9751043338286368
#   },
#   {
#     "Date": "2023-10-20",
#     "ticker": "UNP",
#     "price": 0.9797867377281524
#   },
#   {
#     "Date": "2023-10-23",
#     "ticker": "UNP",
#     "price": 0.9631896033669788
#   },
#   {
#     "Date": "2023-10-24",
#     "ticker": "UNP",
#     "price": 0.9524339608159668
#   },
#   {
#     "Date": "2023-10-25",
#     "ticker": "UNP",
#     "price": 0.9514140200472336
#   },
#   {
#     "Date": "2023-10-26",
#     "ticker": "UNP",
#     "price": 0.937598555190022
#   },
#   {
#     "Date": "2023-10-27",
#     "ticker": "UNP",
#     "price": 0.935187779669308
#   },
#   {
#     "Date": "2023-10-30",
#     "ticker": "UNP",
#     "price": 0.9541029483701852
#   },
#   {
#     "Date": "2023-10-31",
#     "ticker": "UNP",
#     "price": 0.9624942213613854
#   },
#   {
#     "Date": "2023-11-01",
#     "ticker": "UNP",
#     "price": 0.9622624037792562
#   },
#   {
#     "Date": "2023-11-02",
#     "ticker": "UNP",
#     "price": 0.9800185553102816
#   },
#   {
#     "Date": "2023-11-03",
#     "ticker": "UNP",
#     "price": 0.9834492715997288
#   },
#   {
#     "Date": "2023-11-06",
#     "ticker": "UNP",
#     "price": 0.9879462638780174
#   },
#   {
#     "Date": "2023-11-07",
#     "ticker": "UNP",
#     "price": 0.980111296491292
#   },
#   {
#     "Date": "2023-11-08",
#     "ticker": "UNP",
#     "price": 0.9828465600343518
#   },
#   {
#     "Date": "2023-11-09",
#     "ticker": "UNP",
#     "price": 0.9746406986643784
#   },
#   {
#     "Date": "2023-11-10",
#     "ticker": "UNP",
#     "price": 0.98048219047454
#   },
#   {
#     "Date": "2023-11-13",
#     "ticker": "UNP",
#     "price": 0.9707927531715752
#   },
#   {
#     "Date": "2023-11-14",
#     "ticker": "UNP",
#     "price": 0.9999536647798918
#   },
#   {
#     "Date": "2023-11-15",
#     "ticker": "UNP",
#     "price": 1.0110338660940434
#   },
#   {
#     "Date": "2023-11-16",
#     "ticker": "UNP",
#     "price": 1.0169680283444211
#   },
#   {
#     "Date": "2023-11-17",
#     "ticker": "UNP",
#     "price": 1.016272646338828
#   },
#   {
#     "Date": "2023-11-20",
#     "ticker": "UNP",
#     "price": 1.025034813313276
#   },
#   {
#     "Date": "2023-11-21",
#     "ticker": "UNP",
#     "price": 1.029207246828425
#   },
#   {
#     "Date": "2023-11-22",
#     "ticker": "UNP",
#     "price": 1.0361150146274276
#   },
#   {
#     "Date": "2023-11-24",
#     "ticker": "UNP",
#     "price": 1.03977747775821
#   },
#   {
#     "Date": "2023-11-27",
#     "ticker": "UNP",
#     "price": 1.0192397274640168
#   },
#   {
#     "Date": "2023-11-28",
#     "ticker": "UNP",
#     "price": 1.025637454137859
#   },
#   {
#     "Date": "2023-11-29",
#     "ticker": "UNP",
#     "price": 1.0267501360876026
#   },
#   {
#     "Date": "2023-11-30",
#     "ticker": "UNP",
#     "price": 1.0443672112175093
#   },
#   {
#     "Date": "2023-12-01",
#     "ticker": "UNP",
#     "price": 1.0726471877174175
#   },
#   {
#     "Date": "2023-12-04",
#     "ticker": "UNP",
#     "price": 1.0843764358170545
#   },
#   {
#     "Date": "2023-12-05",
#     "ticker": "UNP",
#     "price": 1.0763560568091022
#   },
#   {
#     "Date": "2023-12-06",
#     "ticker": "UNP",
#     "price": 1.0800649259007868
#   },
#   {
#     "Date": "2023-12-07",
#     "ticker": "UNP",
#     "price": 1.0732035640626862
#   },
#   {
#     "Date": "2023-12-08",
#     "ticker": "UNP",
#     "price": 1.065229520274842
#   },
#   {
#     "Date": "2023-12-11",
#     "ticker": "UNP",
#     "price": 1.0757070100236168
#   },
#   {
#     "Date": "2023-12-12",
#     "ticker": "UNP",
#     "price": 1.079786773098549
#   },
#   {
#     "Date": "2023-12-13",
#     "ticker": "UNP",
#     "price": 1.0973111070474455
#   },
#   {
#     "Date": "2023-12-14",
#     "ticker": "UNP",
#     "price": 1.1259156423104937
#   },
#   {
#     "Date": "2023-12-15",
#     "ticker": "UNP",
#     "price": 1.121835879235561
#   },
#   {
#     "Date": "2023-12-18",
#     "ticker": "UNP",
#     "price": 1.1177561869014223
#   },
#   {
#     "Date": "2023-12-19",
#     "ticker": "UNP",
#     "price": 1.1249420367618683
#   },
#   {
#     "Date": "2023-12-20",
#     "ticker": "UNP",
#     "price": 1.1026425577324463
#   },
#   {
#     "Date": "2023-12-21",
#     "ticker": "UNP",
#     "price": 1.1224385908009378
#   },
#   {
#     "Date": "2023-12-22",
#     "ticker": "UNP",
#     "price": 1.1292536174189305
#   },
#   {
#     "Date": "2023-12-26",
#     "ticker": "UNP",
#     "price": 1.137181255245872
#   },
#   {
#     "Date": "2023-12-27",
#     "ticker": "UNP",
#     "price": 1.139592030766586
#   },
#   {
#     "Date": "2023-12-28",
#     "ticker": "UNP",
#     "price": 1.140565636315211
#   },
#   {
#     "Date": "2023-12-29",
#     "ticker": "UNP",
#     "price": 1.1387111663989715
#   },
#   {
#     "Date": "2024-01-02",
#     "ticker": "UNP",
#     "price": 1.1285581646725429
#   },
#   {
#     "Date": "2024-01-03",
#     "ticker": "UNP",
#     "price": 1.1205377856645904
#   },
#   {
#     "Date": "2024-01-04",
#     "ticker": "UNP",
#     "price": 1.1175707045394014
#   },
#   {
#     "Date": "2024-01-05",
#     "ticker": "UNP",
#     "price": 1.1122392538544006
#   },
#   {
#     "Date": "2024-01-08",
#     "ticker": "UNP",
#     "price": 1.1155308230019352
#   },
#   {
#     "Date": "2024-01-09",
#     "ticker": "UNP",
#     "price": 1.1006490821558823
#   },
#   {
#     "Date": "2024-01-10",
#     "ticker": "UNP",
#     "price": 1.1080204143783494
#   },
#   {
#     "Date": "2024-01-11",
#     "ticker": "UNP",
#     "price": 1.0958739370753563
#   },
#   {
#     "Date": "2024-01-12",
#     "ticker": "UNP",
#     "price": 1.1020399169078634
#   },
#   {
#     "Date": "2024-01-16",
#     "ticker": "UNP",
#     "price": 1.0950858138887525
#   },
#   {
#     "Date": "2024-01-17",
#     "ticker": "UNP",
#     "price": 1.093231343972513
#   },
#   {
#     "Date": "2024-01-18",
#     "ticker": "UNP",
#     "price": 1.1033380104788335
#   },
#   {
#     "Date": "2024-01-19",
#     "ticker": "UNP",
#     "price": 1.1092721727292116
#   },
#   {
#     "Date": "2024-01-22",
#     "ticker": "UNP",
#     "price": 1.1270746594803451
#   },
#   {
#     "Date": "2024-01-23",
#     "ticker": "UNP",
#     "price": 1.1280946002490784
#   },
#   {
#     "Date": "2024-01-24",
#     "ticker": "UNP",
#     "price": 1.123458531569671
#   },
#   {
#     "Date": "2024-01-25",
#     "ticker": "UNP",
#     "price": 1.1199351448400072
#   },
#   {
#     "Date": "2024-01-26",
#     "ticker": "UNP",
#     "price": 1.1144645470130938
#   },
#   {
#     "Date": "2024-01-29",
#     "ticker": "UNP",
#     "price": 1.1366249496413972
#   },
#   {
#     "Date": "2024-01-30",
#     "ticker": "UNP",
#     "price": 1.143718129061627
#   },
#   {
#     "Date": "2024-01-31",
#     "ticker": "UNP",
#     "price": 1.1308761990122462
#   },
#   {
#     "Date": "2024-02-01",
#     "ticker": "UNP",
#     "price": 1.1556328595232848
#   },
#   {
#     "Date": "2024-02-02",
#     "ticker": "UNP",
#     "price": 1.151274943646115
#   },
#   {
#     "Date": "2024-02-05",
#     "ticker": "UNP",
#     "price": 1.1434399762593894
#   },
#   {
#     "Date": "2024-02-06",
#     "ticker": "UNP",
#     "price": 1.1584144582864528
#   },
#   {
#     "Date": "2024-02-07",
#     "ticker": "UNP",
#     "price": 1.1551228891389185
#   },
#   {
#     "Date": "2024-02-08",
#     "ticker": "UNP",
#     "price": 1.1535466427657104
#   },
#   {
#     "Date": "2024-02-09",
#     "ticker": "UNP",
#     "price": 1.1564673179299971
#   },
#   {
#     "Date": "2024-02-12",
#     "ticker": "UNP",
#     "price": 1.1469633629890532
#   },
#   {
#     "Date": "2024-02-13",
#     "ticker": "UNP",
#     "price": 1.1386648311788634
#   },
#   {
#     "Date": "2024-02-14",
#     "ticker": "UNP",
#     "price": 1.1595271402361964
#   },
#   {
#     "Date": "2024-02-15",
#     "ticker": "UNP",
#     "price": 1.1615670217736629
#   },
#   {
#     "Date": "2024-02-16",
#     "ticker": "UNP",
#     "price": 1.1432081586772604
#   },
#   {
#     "Date": "2024-02-20",
#     "ticker": "UNP",
#     "price": 1.1457580105990932
#   },
#   {
#     "Date": "2024-02-21",
#     "ticker": "UNP",
#     "price": 1.165136814464229
#   },
#   {
#     "Date": "2024-02-22",
#     "ticker": "UNP",
#     "price": 1.179925814129271
#   },
#   {
#     "Date": "2024-02-23",
#     "ticker": "UNP",
#     "price": 1.191052421404325
#   },
#   {
#     "Date": "2024-02-26",
#     "ticker": "UNP",
#     "price": 1.1712563883358331
#   },
#   {
#     "Date": "2024-02-27",
#     "ticker": "UNP",
#     "price": 1.1742698046811306
#   },
#   {
#     "Date": "2024-02-28",
#     "ticker": "UNP",
#     "price": 1.177515109349351
#   },
#   {
#     "Date": "2024-02-29",
#     "ticker": "UNP",
#     "price": 1.17612427459737
#   },
#   {
#     "Date": "2024-03-01",
#     "ticker": "UNP",
#     "price": 1.1728326347090414
#   },
#   {
#     "Date": "2024-03-04",
#     "ticker": "UNP",
#     "price": 1.1751043338286369
#   },
#   {
#     "Date": "2024-03-05",
#     "ticker": "UNP",
#     "price": 1.1761706098174782
#   },
#   {
#     "Date": "2024-03-06",
#     "ticker": "UNP",
#     "price": 1.1636532385312373
#   },
#   {
#     "Date": "2024-03-07",
#     "ticker": "UNP",
#     "price": 1.1545665127936495
#   },
#   {
#     "Date": "2024-03-08",
#     "ticker": "UNP",
#     "price": 1.1634678269100105
#   },
#   {
#     "Date": "2024-03-11",
#     "ticker": "UNP",
#     "price": 1.1584144582864528
#   },
#   {
#     "Date": "2024-03-12",
#     "ticker": "UNP",
#     "price": 1.1644876969379494
#   },
#   {
#     "Date": "2024-03-13",
#     "ticker": "UNP",
#     "price": 1.1555401183422744
#   },
#   {
#     "Date": "2024-03-14",
#     "ticker": "UNP",
#     "price": 1.140751047936438
#   },
#   {
#     "Date": "2024-03-15",
#     "ticker": "UNP",
#     "price": 1.131803469340763
#   },
#   {
#     "Date": "2024-03-18",
#     "ticker": "UNP",
#     "price": 1.1328697453296044
#   },
#   {
#     "Date": "2024-03-19",
#     "ticker": "UNP",
#     "price": 1.1252202603049
#   },
#   {
#     "Date": "2024-03-20",
#     "ticker": "UNP",
#     "price": 1.14191006510629
#   },
#   {
#     "Date": "2024-03-21",
#     "ticker": "UNP",
#     "price": 1.1502550028773817
#   },
#   {
#     "Date": "2024-03-22",
#     "ticker": "UNP",
#     "price": 1.135697750053675
#   },
#   {
#     "Date": "2024-03-25",
#     "ticker": "UNP",
#     "price": 1.1305053757697925
#   },
#   {
#     "Date": "2024-03-26",
#     "ticker": "UNP",
#     "price": 1.1158553817650747
#   },
#   {
#     "Date": "2024-03-27",
#     "ticker": "UNP",
#     "price": 1.1341215036804666
#   },
#   {
#     "Date": "2024-03-28",
#     "ticker": "UNP",
#     "price": 1.140148336371061
#   },
#   {
#     "Date": "2024-04-01",
#     "ticker": "UNP",
#     "price": 1.1279555238479595
#   },
#   {
#     "Date": "2024-04-02",
#     "ticker": "UNP",
#     "price": 1.1243857311573937
#   },
#   {
#     "Date": "2024-04-03",
#     "ticker": "UNP",
#     "price": 1.119842403658997
#   },
#   {
#     "Date": "2024-04-04",
#     "ticker": "UNP",
#     "price": 1.1158553817650747
#   },
#   {
#     "Date": "2024-04-05",
#     "ticker": "UNP",
#     "price": 1.1219749556366796
#   },
#   {
#     "Date": "2024-04-08",
#     "ticker": "UNP",
#     "price": 1.1140009118488354
#   },
#   {
#     "Date": "2024-04-09",
#     "ticker": "UNP",
#     "price": 1.116318946188539
#   },
#   {
#     "Date": "2024-04-10",
#     "ticker": "UNP",
#     "price": 1.0980528950139412
#   },
#   {
#     "Date": "2024-04-11",
#     "ticker": "UNP",
#     "price": 1.094853996306623
#   },
#   {
#     "Date": "2024-04-12",
#     "ticker": "UNP",
#     "price": 1.086694470156758
#   },
#   {
#     "Date": "2024-04-15",
#     "ticker": "UNP",
#     "price": 1.084561918179075
#   },
#   {
#     "Date": "2024-04-16",
#     "ticker": "UNP",
#     "price": 1.0721372173330508
#   },
#   {
#     "Date": "2024-04-17",
#     "ticker": "UNP",
#     "price": 1.0627260035731174
#   },
#   {
#     "Date": "2024-04-18",
#     "ticker": "UNP",
#     "price": 1.065414931896069
#   },
#   {
#     "Date": "2024-04-19",
#     "ticker": "UNP",
#     "price": 1.075938827605746
#   },
#   {
#     "Date": "2024-04-22",
#     "ticker": "UNP",
#     "price": 1.0870190289198978
#   },
#   {
#     "Date": "2024-04-23",
#     "ticker": "UNP",
#     "price": 1.0954566371312062
#   },
#   {
#     "Date": "2024-04-24",
#     "ticker": "UNP",
#     "price": 1.0754751924414876
#   },
#   {
#     "Date": "2024-04-25",
#     "ticker": "UNP",
#     "price": 1.1291145410178114
#   },
#   {
#     "Date": "2024-04-26",
#     "ticker": "UNP",
#     "price": 1.1255910835473537
#   },
#   {
#     "Date": "2024-04-29",
#     "ticker": "UNP",
#     "price": 1.1170607341550347
#   },
#   {
#     "Date": "2024-04-30",
#     "ticker": "UNP",
#     "price": 1.0994900649860304
#   },
#   {
#     "Date": "2024-05-01",
#     "ticker": "UNP",
#     "price": 1.0892907280394932
#   },
#   {
#     "Date": "2024-05-02",
#     "ticker": "UNP",
#     "price": 1.1019471757268529
#   },
#   {
#     "Date": "2024-05-03",
#     "ticker": "UNP",
#     "price": 1.1143254706119752
#   },
#   {
#     "Date": "2024-05-06",
#     "ticker": "UNP",
#     "price": 1.1089940199269743
#   },
#   {
#     "Date": "2024-05-07",
#     "ticker": "UNP",
#     "price": 1.1236903491518002
#   },
#   {
#     "Date": "2024-05-08",
#     "ticker": "UNP",
#     "price": 1.1400092599699423
#   },
#   {
#     "Date": "2024-05-09",
#     "ticker": "UNP",
#     "price": 1.1433008998582708
#   },
#   {
#     "Date": "2024-05-10",
#     "ticker": "UNP",
#     "price": 1.1469633629890532
#   },
#   {
#     "Date": "2024-05-13",
#     "ticker": "UNP",
#     "price": 1.138989319201209
#   },
#   {
#     "Date": "2024-05-14",
#     "ticker": "UNP",
#     "price": 1.1355586736525558
#   },
#   {
#     "Date": "2024-05-15",
#     "ticker": "UNP",
#     "price": 1.1429763410951312
#   },
#   {
#     "Date": "2024-05-16",
#     "ticker": "UNP",
#     "price": 1.1400092599699423
#   },
#   {
#     "Date": "2024-05-17",
#     "ticker": "UNP",
#     "price": 1.135697750053675
#   },
#   {
#     "Date": "2024-05-20",
#     "ticker": "UNP",
#     "price": 1.1294854350010592
#   },
#   {
#     "Date": "2024-05-21",
#     "ticker": "UNP",
#     "price": 1.0892907280394932
#   },
#   {
#     "Date": "2024-05-22",
#     "ticker": "UNP",
#     "price": 1.0881317108696411
#   },
#   {
#     "Date": "2024-05-23",
#     "ticker": "UNP",
#     "price": 1.0788595735108266
#   },
#   {
#     "Date": "2024-05-24",
#     "ticker": "UNP",
#     "price": 1.0757997512046271
#   },
#   {
#     "Date": "2024-05-28",
#     "ticker": "UNP",
#     "price": 1.0617060628043844
#   },
#   {
#     "Date": "2024-05-29",
#     "ticker": "UNP",
#     "price": 1.0471952159415794
#   },
#   {
#     "Date": "2024-05-30",
#     "ticker": "UNP",
#     "price": 1.06277240953402
#   },
#   {
#     "Date": "2024-05-31",
#     "ticker": "UNP",
#     "price": 1.0793695438951934
#   },
#   {
#     "Date": "2024-06-03",
#     "ticker": "UNP",
#     "price": 1.0585072348378604
#   },
#   {
#     "Date": "2024-06-04",
#     "ticker": "UNP",
#     "price": 1.05526193016964
#   },
#   {
#     "Date": "2024-06-05",
#     "ticker": "UNP",
#     "price": 1.0542883953618092
#   },
#   {
#     "Date": "2024-06-06",
#     "ticker": "UNP",
#     "price": 1.058460828876958
#   },
#   {
#     "Date": "2024-06-07",
#     "ticker": "UNP",
#     "price": 1.05688458250375
#   },
#   {
#     "Date": "2024-06-10",
#     "ticker": "UNP",
#     "price": 1.061427910002147
#   },
#   {
#     "Date": "2024-06-11",
#     "ticker": "UNP",
#     "price": 1.0542883953618092
#   },
#   {
#     "Date": "2024-06-12",
#     "ticker": "UNP",
#     "price": 1.0499304794846391
#   },
#   {
#     "Date": "2024-06-13",
#     "ticker": "UNP",
#     "price": 1.0297635524328996
#   },
#   {
#     "Date": "2024-06-14",
#     "ticker": "UNP",
#     "price": 1.0296708819926832
#   },
#   {
#     "Date": "2024-06-17",
#     "ticker": "UNP",
#     "price": 1.0263329068842464
#   },
#   {
#     "Date": "2024-06-18",
#     "ticker": "UNP",
#     "price": 1.0318961751513764
#   },
#   {
#     "Date": "2024-06-20",
#     "ticker": "UNP",
#     "price": 1.043903576053251
#   },
#   {
#     "Date": "2024-06-21",
#     "ticker": "UNP",
#     "price": 1.0482614919304207
#   },
#   {
#     "Date": "2024-06-24",
#     "ticker": "UNP",
#     "price": 1.0494205091002726
#   },
#   {
#     "Date": "2024-06-25",
#     "ticker": "UNP",
#     "price": 1.038757536989477
#   },
#   {
#     "Date": "2024-06-26",
#     "ticker": "UNP",
#     "price": 1.0366713202319024
#   },
#   {
#     "Date": "2024-06-27",
#     "ticker": "UNP",
#     "price": 1.0360222734464173
#   },
#   {
#     "Date": "2024-06-28",
#     "ticker": "UNP",
#     "price": 1.0489568739360142
#   },
#   {
#     "Date": "2024-07-01",
#     "ticker": "UNP",
#     "price": 1.0424664060811617
#   },
#   {
#     "Date": "2024-07-02",
#     "ticker": "UNP",
#     "price": 1.0454334872063509
#   },
#   {
#     "Date": "2024-07-03",
#     "ticker": "UNP",
#     "price": 1.0457580459694902
#   },
#   {
#     "Date": "2024-07-05",
#     "ticker": "UNP",
#     "price": 1.043903576053251
#   },
#   {
#     "Date": "2024-07-08",
#     "ticker": "UNP",
#     "price": 1.0356513794631694
#   },
#   {
#     "Date": "2024-07-09",
#     "ticker": "UNP",
#     "price": 1.0281873060596918
#   },
#   {
#     "Date": "2024-07-10",
#     "ticker": "UNP",
#     "price": 1.0403801893235871
#   },
#   {
#     "Date": "2024-07-11",
#     "ticker": "UNP",
#     "price": 1.0603616340133055
#   },
#   {
#     "Date": "2024-07-12",
#     "ticker": "UNP",
#     "price": 1.067315737032417
#   },
#   {
#     "Date": "2024-07-15",
#     "ticker": "UNP",
#     "price": 1.0940658731200192
#   },
#   {
#     "Date": "2024-07-16",
#     "ticker": "UNP",
#     "price": 1.126842841898216
#   },
#   {
#     "Date": "2024-07-17",
#     "ticker": "UNP",
#     "price": 1.1306907873910197
#   },
#   {
#     "Date": "2024-07-18",
#     "ticker": "UNP",
#     "price": 1.126611024316087
#   },
#   {
#     "Date": "2024-07-19",
#     "ticker": "UNP",
#     "price": 1.123412196349563
#   },
#   {
#     "Date": "2024-07-22",
#     "ticker": "UNP",
#     "price": 1.1278164474468408
#   },
#   {
#     "Date": "2024-07-23",
#     "ticker": "UNP",
#     "price": 1.110338448718053
#   },
#   {
#     "Date": "2024-07-24",
#     "ticker": "UNP",
#     "price": 1.1005100057547637
#   },
#   {
#     "Date": "2024-07-25",
#     "ticker": "UNP",
#     "price": 1.0910987919948305
#   },
#   {
#     "Date": "2024-07-26",
#     "ticker": "UNP",
#     "price": 1.1143254706119752
#   },
#   {
#     "Date": "2024-07-29",
#     "ticker": "UNP",
#     "price": 1.1226240024221648
#   },
#   {
#     "Date": "2024-07-30",
#     "ticker": "UNP",
#     "price": 1.1378303020313574
#   }
# ]
# Financial Data: [
#   {
#     "date": "2023-12-31",
#     "symbol": "UNP",
#     "reportedCurrency": "USD",
#     "cik": 100885,
#     "fillingDate": "2024-02-09",
#     "acceptedDate": "2024-02-09 13:56:24",
#     "calendarYear": 2023,
#     "period": "FY",
#     "revenue": 24119000000,
#     "costOfRevenue": 13590000000,
#     "grossProfit": 10529000000,
#     "grossProfitRatio": 0.4365438036,
#     "researchAndDevelopmentExpenses": 0.0,
#     "generalAndAdministrativeExpenses": 0,
#     "sellingAndMarketingExpenses": 0,
#     "sellingGeneralAndAdministrativeExpenses": 1447000000.0,
#     "otherExpenses": 25000000,
#     "operatingExpenses": 1447000000,
#     "costAndExpenses": 15037000000,
#     "interestIncome": 52000000,
#     "interestExpense": 1340000000,
#     "depreciationAndAmortization": 167895,
#     "ebitda": 11477000000,
#     "ebitdaratio": 0.4758489158,
#     "operatingIncome": 9082000000,
#     "operatingIncomeRatio": 0.3765496082,
#     "totalOtherIncomeExpensesNet": 439000000,
#     "incomeBeforeTax": 8233000000,
#     "incomeBeforeTaxRatio": 0.3413491438,
#     "incomeTaxExpense": 1854000000,
#     "netIncome": 6379000000,
#     "netIncomeRatio": 0.2644802853,
#     "eps": 10.47,
#     "epsdiluted": 10.45,
#     "weightedAverageShsOut": 609200000,
#     "weightedAverageShsOutDil": 610200000,
#     "link": "https://www.sec.gov/Archives/edgar/data/100885/000143774924003599/0001437749-24-003599-index.htm",
#     "finalLink": "https://www.sec.gov/Archives/edgar/data/100885/000143774924003599/unp20231231_10k.htm",
#     "ticker": "UNP"
#   },
#   {
#     "date": "2022-12-31",
#     "symbol": "UNP",
#     "reportedCurrency": "USD",
#     "cik": 100885,
#     "fillingDate": "2023-02-10",
#     "acceptedDate": "2023-02-10 09:42:02",
#     "calendarYear": 2022,
#     "period": "FY",
#     "revenue": 24875000000,
#     "costOfRevenue": 13670000000,
#     "grossProfit": 11205000000,
#     "grossProfitRatio": 0.4504522613,
#     "researchAndDevelopmentExpenses": 0.0,
#     "generalAndAdministrativeExpenses": 0,
#     "sellingAndMarketingExpenses": 0,
#     "sellingGeneralAndAdministrativeExpenses": 1288000000.0,
#     "otherExpenses": 1288000000,
#     "operatingExpenses": 1288000000,
#     "costAndExpenses": 14958000000,
#     "interestIncome": 23000000,
#     "interestExpense": 1271000000,
#     "depreciationAndAmortization": 228485,
#     "ebitda": 12589000000,
#     "ebitdaratio": 0.5060904523,
#     "operatingIncome": 9917000000,
#     "operatingIncomeRatio": 0.3986733668,
#     "totalOtherIncomeExpensesNet": -845000000,
#     "incomeBeforeTax": 9072000000,
#     "incomeBeforeTaxRatio": 0.3647035176,
#     "incomeTaxExpense": 2074000000,
#     "netIncome": 6998000000,
#     "netIncomeRatio": 0.2813266332,
#     "eps": 11.24,
#     "epsdiluted": 11.21,
#     "weightedAverageShsOut": 622700000,
#     "weightedAverageShsOutDil": 624000000,
#     "link": "https://www.sec.gov/Archives/edgar/data/100885/000143774923002959/0001437749-23-002959-index.htm",
#     "finalLink": "https://www.sec.gov/Archives/edgar/data/100885/000143774923002959/unp20221231_10k.htm",
#     "ticker": "UNP"
#   },
#   {
#     "date": "2021-12-31",
#     "symbol": "UNP",
#     "reportedCurrency": "USD",
#     "cik": 100885,
#     "fillingDate": "2022-02-04",
#     "acceptedDate": "2022-02-04 15:59:07",
#     "calendarYear": 2021,
#     "period": "FY",
#     "revenue": 21804000000,
#     "costOfRevenue": 11290000000,
#     "grossProfit": 10514000000,
#     "grossProfitRatio": 0.4822051,
#     "researchAndDevelopmentExpenses": 0.0,
#     "generalAndAdministrativeExpenses": 0,
#     "sellingAndMarketingExpenses": 0,
#     "sellingGeneralAndAdministrativeExpenses": 1176000000.0,
#     "otherExpenses": 1176000000,
#     "operatingExpenses": 1176000000,
#     "costAndExpenses": 12466000000,
#     "interestIncome": 5000000,
#     "interestExpense": 1157000000,
#     "depreciationAndAmortization": 236558,
#     "ebitda": 11843000000,
#     "ebitdaratio": 0.5431572189,
#     "operatingIncome": 9338000000,
#     "operatingIncomeRatio": 0.4282700422,
#     "totalOtherIncomeExpensesNet": -860000000,
#     "incomeBeforeTax": 8478000000,
#     "incomeBeforeTaxRatio": 0.388827738,
#     "incomeTaxExpense": 1955000000,
#     "netIncome": 6523000000,
#     "netIncomeRatio": 0.2991652908,
#     "eps": 9.98,
#     "epsdiluted": 9.95,
#     "weightedAverageShsOut": 653800000,
#     "weightedAverageShsOutDil": 655400000,
#     "link": "https://www.sec.gov/Archives/edgar/data/100885/000143774922002494/0001437749-22-002494-index.htm",
#     "finalLink": "https://www.sec.gov/Archives/edgar/data/100885/000143774922002494/unp20211231_10k.htm",
#     "ticker": "UNP"
#   },
#   {
#     "date": "2020-12-31",
#     "symbol": "UNP",
#     "reportedCurrency": "USD",
#     "cik": 100885,
#     "fillingDate": "2021-02-05",
#     "acceptedDate": "2021-02-05 16:35:25",
#     "calendarYear": 2020,
#     "period": "FY",
#     "revenue": 19533000000,
#     "costOfRevenue": 10354000000,
#     "grossProfit": 9179000000,
#     "grossProfitRatio": 0.4699226949,
#     "researchAndDevelopmentExpenses": 0.0,
#     "generalAndAdministrativeExpenses": 0,
#     "sellingAndMarketingExpenses": 0,
#     "sellingGeneralAndAdministrativeExpenses": 1576000000.0,
#     "otherExpenses": 1345000000,
#     "operatingExpenses": 1345000000,
#     "costAndExpenses": 11699000000,
#     "interestIncome": 12000000,
#     "interestExpense": 1141000000,
#     "depreciationAndAmortization": 206297,
#     "ebitda": 10331000000,
#     "ebitdaratio": 0.5288998106,
#     "operatingIncome": 7834000000,
#     "operatingIncomeRatio": 0.4010648646,
#     "totalOtherIncomeExpensesNet": -854000000,
#     "incomeBeforeTax": 6980000000,
#     "incomeBeforeTaxRatio": 0.357343982,
#     "incomeTaxExpense": 1631000000,
#     "netIncome": 5349000000,
#     "netIncomeRatio": 0.2738442636,
#     "eps": 7.9,
#     "epsdiluted": 7.88,
#     "weightedAverageShsOut": 677300000,
#     "weightedAverageShsOutDil": 679100000,
#     "link": "https://www.sec.gov/Archives/edgar/data/100885/000010088521000068/0000100885-21-000068-index.htm",
#     "finalLink": "https://www.sec.gov/Archives/edgar/data/100885/000010088521000068/unp-20201231x10k.htm",
#     "ticker": "UNP"
#   },
#   {
#     "date": "2019-12-31",
#     "symbol": "UNP",
#     "reportedCurrency": "USD",
#     "cik": 100885,
#     "fillingDate": "2020-02-07",
#     "acceptedDate": "2020-02-07 15:35:18",
#     "calendarYear": 2019,
#     "period": "FY",
#     "revenue": 21708000000,
#     "costOfRevenue": 12094000000,
#     "grossProfit": 9614000000,
#     "grossProfitRatio": 0.4428782016,
#     "researchAndDevelopmentExpenses": 0.0,
#     "generalAndAdministrativeExpenses": 0,
#     "sellingAndMarketingExpenses": 0,
#     "sellingGeneralAndAdministrativeExpenses": 1275000000.0,
#     "otherExpenses": 1060000000,
#     "operatingExpenses": 1060000000,
#     "costAndExpenses": 13154000000,
#     "interestIncome": 63000000,
#     "interestExpense": 1050000000,
#     "depreciationAndAmortization": 171860,
#     "ebitda": 11013000000,
#     "ebitdaratio": 0.5073244887,
#     "operatingIncome": 8554000000,
#     "operatingIncomeRatio": 0.3940482771,
#     "totalOtherIncomeExpensesNet": -807000000,
#     "incomeBeforeTax": 7747000000,
#     "incomeBeforeTaxRatio": 0.3568730422,
#     "incomeTaxExpense": 1828000000,
#     "netIncome": 5919000000,
#     "netIncomeRatio": 0.2726644555,
#     "eps": 8.41,
#     "epsdiluted": 8.38,
#     "weightedAverageShsOut": 703500000,
#     "weightedAverageShsOutDil": 706100000,
#     "link": "https://www.sec.gov/Archives/edgar/data/100885/000010088520000065/0000100885-20-000065-index.htm",
#     "finalLink": "https://www.sec.gov/Archives/edgar/data/100885/000010088520000065/unp-20191231x10k.htm",
#     "ticker": "UNP"
#   }
# ]
# News Data: [
#   {
#     "ticker": "UNP",
#     "title": "8 out of 10 S&P 500 materials stocks deliver EPS wins this week: Earnings Scorecard",
#     "description": "No description",
#     "url": "/news/4133384-8-out-of-10-sp-500-materials-stocks-deliver-eps-wins-this-week-earnings-scorecard#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Libya is said to begin cutting output at biggest oil field",
#     "description": "No description",
#     "url": "/news/4133697-libya-is-said-to-begin-cutting-output-at-biggest-oil-field#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "19 out of 25 Information Technology companies topped profit estimates this week: Earnings Scorecard",
#     "description": "No description",
#     "url": "/news/4133361-20-out-of-25-information-technology-companies-topped-profit-estimates-this-week-earnings-scorecard#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Boeing's new CEO will confront key issues with plane output, cash flow: Morgan Stanley",
#     "description": "No description",
#     "url": "/news/4133695-boeings-new-ceo-will-confront-key-issues-with-plane-output-cash-flow-morgan-stanley#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Over 80% of companies that reported earnings this week beat profit estimates - Earnings Scorecard",
#     "description": "No description",
#     "url": "/news/4133662-over-80-of-companies-that-reported-earnings-this-week-beat-profit-estimates-earnings-scorecard#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Venture Global LNG sues Kiewit for sharing confidential information with Shell",
#     "description": "No description",
#     "url": "/news/4133694-venture-global-lng-sues-kiewit-for-sharing-confidential-information-with-shell#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Dynatrace, Elastic, JFrog, SentinelOne, Zoom Video potential M&A targets - analyst",
#     "description": "No description",
#     "url": "/news/4133693-dynatrace-elastic-jfrog-sentinelone-zoom-video-potential-ma-targets-analyst#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "DoorDash Q2 results underscore potential for increased vertical expansion",
#     "description": "No description",
#     "url": "/news/4133683-doordash-q2-results-underscore-potential-for-increased-vertical-expansion#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Earnings week ahead: Disney, Duke Energy, Palantir, Shopify, Uber and more",
#     "description": "No description",
#     "url": "/news/4133349-earnings-week-ahead-disney-duke-energy-palantir-shopify-uber-plug-power-nikola-and-more#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Chevron moving to Texas, says California policies discourage investment and hurt consumers",
#     "description": "No description",
#     "url": "/news/4133654-chevron-moving-to-texas-says-california-policies-discourage-investment-and-hurt-consumers#source=first_level_url%3Amarket-news%7Csection_asset%3Amain",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "News & Insights",
#     "description": "Options trading has become increasingly popular in recent years. Given options are different to stocks, we thought it was time to do an intern's guide for U.S. options to help you understand options and options markets work.",
#     "url": "/market-activity/stocks/adbe",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "No title",
#     "description": "By Nicholas Jasinski",
#     "url": "https://www.barrons.com/articles/disney-super-micro-uber-paramount-stocks-earnings-c7e26916",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "No title",
#     "description": "By Brian Swint",
#     "url": "https://www.barrons.com/articles/bank-england-rate-decision-federal-reserve-5c192b69",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "No title",
#     "description": "By Brian Swint",
#     "url": "https://www.barrons.com/articles/shell-stock-earnings-bp-exxon-chevron-9fd8f2dc",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "No title",
#     "description": "By Nicholas Jasinski",
#     "url": "https://www.barrons.com/articles/jobs-report-fed-interest-rates-economy-25a75fbf",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "No title",
#     "description": "Low ball offers, car dealerships, online selling tools. I experienced it all trying to move my one-year-old Tesla Model 3. ",
#     "url": "https://www.barrons.com/articles/i-sold-my-tesla-heres-how-i-did-e2b807a8?mod=md_home_pan_mkt_news",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Harris tech ties complicate Trump effort to win over Silicon Valley",
#     "description": "A slumping stock market greets investors concerned about the impact of high interest rates on the US economy.",
#     "url": "/quote/%5EGSPC/",
#     "publishedAt": "No date"
#   },
#   {
#     "ticker": "UNP",
#     "title": "Neuralink implanted second trial patient with brain chip, Musk says",
#     "description": "(Bloomberg) -- Australia is poised to stay near the back of the global easing cycle as local inflation \u2014 while cooling \u2014 remains elevated requiring the Reserve Bank to keep its key interest rate at a 12-year high.Most Read from BloombergSinger Akon\u2019s Multibillion-Dollar Futuristic City in Africa Gets Final NoticeWhat a Beautiful Bus Stop Can DoValencia Follows Barcelona in Crackdown on Short-Term RentalsA Vast Wetland Park Seeks to Slake a Thirsty MegacityA Radical Fix for Britain\u2019s Housing Cris",
#     "url": "/quote/%5EGSPC/",
#     "publishedAt": "No date"
#   }
# ]
#
# Suggestion:
# Based on the provided data, the stock UNP has shown a downward trend in its price over the past few weeks, with a significant drop from $1.179181 on 2024-02-22 to $1.026332 on 2024-02-26. This trend is concerning and suggests a bearish outlook for the stock.
#
# However, the financial data shows that the company

# %%
from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain
import pandas as pd
import json

# Load datasets
stock_data = pd.read_csv('100_stocks_data_new.csv', index_col='Date')
financial_data = pd.read_csv('financial_statements_fmp.csv')
news_data = pd.read_csv('news_articles_100_tickers.csv')

# Transform stock data to have a ticker column
stock_data = stock_data.reset_index().melt(id_vars='Date', var_name='ticker', value_name='price')

# Define prompt template
template = """
Based on the following data, provide an investment suggestion for the ticker {ticker}:
Stock Data: {stock_data}
Financial Data: {financial_data}
News Data: {news_data}

Suggestion:
"""

prompt = PromptTemplate(
    input_variables=["ticker", "stock_data", "financial_data", "news_data"],
    template=template
)

# Load LLM from Hugging Face with the API token
llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3", 
    model_kwargs={"use_auth_token": "YOUR_HF_AUTH_TOKEN"},
    huggingfacehub_api_token="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"
)

# Define LLM Chain
llm_chain = LLMChain(prompt=prompt, llm=llm)

def combine_data_for_ticker(ticker):
    stock_info = stock_data[stock_data['ticker'] == ticker].to_dict(orient='records')
    financial_info = financial_data[financial_data['ticker'] == ticker].to_dict(orient='records')
    news_info = news_data[news_data['ticker'] == ticker].to_dict(orient='records')

    stock_summary = f"Price data points: {len(stock_info)}"
    financial_summary = f"Latest report: {financial_info[0] if financial_info else 'No data'}"
    news_summary = f"News articles count: {len(news_info)}"

    combined_data = {
        'ticker': ticker,
        'stock_summary': stock_summary,
        'financial_summary': financial_summary,
        'news_summary': news_summary
    }
    
    return combined_data

def get_investment_suggestion(ticker):
    combined_data = combine_data_for_ticker(ticker)
    stock_summary = combined_data['stock_summary']
    financial_summary = combined_data['financial_summary']
    news_summary = combined_data['news_summary']
    
    suggestion = llm_chain.run(
        ticker=ticker,
        stock_data=stock_summary,
        financial_data=financial_summary,
        news_data=news_summary
    )
    return suggestion

def prompt_user_for_ticker():
    ticker = input("Enter the ticker symbol (e.g., AAPL): ").upper()
    suggestion = get_investment_suggestion(ticker)
    print(f"Investment Suggestion for {ticker}:")
    print(suggestion)

# Example usage
prompt_user_for_ticker()
# Out:
# C:\Users\kteja\anaconda3\envs\llm_finance\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEndpoint`.
#   warn_deprecated(
# C:\Users\kteja\anaconda3\envs\llm_finance\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# Enter the ticker symbol (e.g., AAPL):  AAPL
# C:\Users\kteja\anaconda3\envs\llm_finance\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Investment Suggestion for AAPL:
#
# Based on the following data, provide an investment suggestion for the ticker AAPL:
# Stock Data: Price data points: 220
# Financial Data: Latest report: {'date': '2023-09-30', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik': 320193, 'fillingDate': '2023-11-03', 'acceptedDate': '2023-11-02 18:08:27', 'calendarYear': 2023, 'period': 'FY', 'revenue': 383285000000, 'costOfRevenue': 214137000000, 'grossProfit': 169148000000, 'grossProfitRatio': 0.4413112958, 'researchAndDevelopmentExpenses': 29915000000.0, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 24932000000.0, 'otherExpenses': 382000000, 'operatingExpenses': 55229000000, 'costAndExpenses': 269366000000, 'interestIncome': 3750000000, 'interestExpense': 3933000000, 'depreciationAndAmortization': 167895, 'ebitda': 125820000000, 'ebitdaratio': 0.3282674772, 'operatingIncome': 114301000000, 'operatingIncomeRatio': 0.2982141227, 'totalOtherIncomeExpensesNet': -565000000, 'incomeBeforeTax': 113736000000, 'incomeBeforeTaxRatio': 0.2967400237, 'incomeTaxExpense': 16741000000, 'netIncome': 96995000000, 'netIncomeRatio': 0.2530623426, 'eps': 6.16, 'epsdiluted': 6.13, 'weightedAverageShsOut': 15744231000, 'weightedAverageShsOutDil': 15812547000, 'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm', 'ticker': 'AAPL'}
# News Data: News articles count: 18
#
# Suggestion:
# Based on the provided financial data, Apple Inc. (AAPL) reported a net income of $96,995,000,000 for the fiscal year 2023, with an EPS of $6.16. The gross profit ratio was 0.4413, and the EBITDA was $12,582,000,000. The stock price at the time of analysis was

# %%
import os
import streamlit as st
import pandas as pd
import json
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain

# Set environment variable for protobuf
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

# Load datasets
stock_data = pd.read_csv('100_stock_data.csv', index_col='Date')
financial_data = pd.read_csv('financial_statements_fmp.csv')
news_data = pd.read_csv('news_articles_100_tickers.csv')

# Transform stock data to have a ticker column
stock_data = stock_data.reset_index().melt(id_vars='Date', var_name='ticker', value_name='price')

# Define prompt template
template = """
Based on the following data, provide an investment suggestion for the ticker {ticker}:
Stock Summary: {stock_summary}
Financial Summary: {financial_summary}
News Summary: {news_summary}

Suggestion:
"""

prompt = PromptTemplate(
    input_variables=["ticker", "stock_summary", "financial_summary", "news_summary"],
    template=template
)

# Load LLM from Hugging Face
llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    model_kwargs={"use_auth_token": "YOUR_HF_AUTH_TOKEN"},
    huggingfacehub_api_token="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"
)

# Define LLM Chain
llm_chain = LLMChain(prompt=prompt, llm=llm)

def combine_data_for_ticker(ticker):
    stock_info = stock_data[stock_data['ticker'] == ticker].to_dict(orient='records')
    financial_info = financial_data[financial_data['ticker'] == ticker].to_dict(orient='records')
    news_info = news_data[news_data['ticker'] == ticker].to_dict(orient='records')
    
    stock_summary = f"Price data points: {len(stock_info)}"
    financial_summary = f"Latest report: {financial_info[0] if financial_info else 'No data'}"
    news_summary = f"News articles count: {len(news_info)}"

    combined_data = {
        'ticker': ticker,
        'stock_summary': stock_summary,
        'financial_summary': financial_summary,
        'news_summary': news_summary
    }
    
    return combined_data

def get_investment_suggestion(ticker):
    combined_data = combine_data_for_ticker(ticker)
    stock_summary = combined_data['stock_summary']
    financial_summary = combined_data['financial_summary']
    news_summary = combined_data['news_summary']
    
    suggestion = llm_chain.run(
        ticker=ticker,
        stock_summary=stock_summary,
        financial_summary=financial_summary,
        news_summary=news_summary
    )
    return suggestion

# Streamlit app
st.title("Investment Suggestion Chatbot")
st.write("Enter a ticker symbol to get an investment suggestion based on stock, financial, and news data.")

ticker_input = st.text_input("Ticker Symbol (e.g., AAPL)").upper()

if st.button("Get Suggestion"):
    if ticker_input:
        suggestion = get_investment_suggestion(ticker_input)
        st.write(f"Investment Suggestion for {ticker_input}:")
        st.write(suggestion)
    else:
        st.write("Please enter a ticker symbol.")
# Out:
# 2024-08-04 19:50:34.320
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\kteja\anaconda3\envs\llm_finance\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-08-04 19:50:34.321 Session state does not function when running a script without `streamlit run`
